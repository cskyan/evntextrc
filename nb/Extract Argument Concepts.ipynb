# %%
import os, sys, json

import numpy as np
import pandas as pd

from bionlp.util import fs, io, func
from bionlp.spider import pubtator

sys.path.append(os.path.join(os.path.expanduser('~'), 'source', 'py', 'evntextrc', 'bin'))
import bnlpst

DATA_PATH = os.path.join(os.path.expanduser('~'), 'data', 'bioevent', 'bnlpst')
YEAR = '2011'
TASK = 'bgi'
TRAIN_DATA_PATH = os.path.join(DATA_PATH, YEAR, TASK, 'train')
DEV_DATA_PATH = os.path.join(DATA_PATH, YEAR, TASK, 'dev')
TEST_DATA_PATH = os.path.join(DATA_PATH, YEAR, TASK, 'test')

# %%
# Use PubTator to obtain the annotated concepts from the related PubMed data
pubtator_cli = pubtator.PubTatorAPI()

entity_by_type, concept_map, from_pmid = {}, {}, {}

for ds_path in [TRAIN_DATA_PATH, DEV_DATA_PATH]:
    for fpath in fs.listf(ds_path, pattern='.*.a1', full_path=True):
        prgrphs = pubtator_cli.get_concepts_pmid('all', fpath.split('-')[1])
        concepts = func.flatten_list([[(prgrph['text'][concept['span']['begin']:concept['span']['end']], concept['obj']) for concept in prgrph['denotations'] if concept['obj']] for prgrph in prgrphs if len(prgrph['denotations'])>0])
        concept_map.update(dict(concepts))
        sent_bndry, words, annots, gddfs, coref = bnlpst.get_a1_2011(fpath, disable=['parse'])
        for ent_type, ent_str in zip(annots['type'], annots['str']):
            entity_by_type.setdefault(ent_type, set([])).add(ent_str.lower())
            from_pmid.setdefault(ent_str.lower(), []).append(fpath.split('-')[1])
entity_by_type = dict([(k, list(v)) for k, v in entity_by_type.items()])

# %%
# Append the PMIDs
entity_concept_by_type = dict([(k, [(s, [c for w, c in concept_map.items() if w in s], from_pmid.setdefault(s, [])) for s in v]) for k, v in entity_by_type.items()])

# %%
concept_map
# Out:
# {u'116-124': u'Chemical:C448907',
#  u'13-amino-acid': u'Chemical:',
#  u'14-amino-acid': u'Chemical:',
#  u'2-keto-3-deoxygluconate': u'Chemical:C002957',
#  u'2-keto-3-deoxygluconate-6-phosphate': u'Chemical:',
#  u'267:12055-12060': u'Chemical:C024336',
#  u'A/T': u'Mutation:c|SUB|A||T',
#  u'A863G': u'Mutation:c|SUB|A|863|G',
#  u'ATP': u'Chemical:D000255',
#  u'Alanine': u'Chemical:CHEBI:16449',
#  u'Amino acid': u'Chemical:CHEBI:33704',
#  u'Arginine': u'Chemical:CHEBI:29016',
#  u'Asp': u'Chemical:CHEBI:22660',
#  u'B. subtilis': u'Species:1423',
#  u'B. subtilis 168': u'Species:224308',
#  u'B. subtilis strain': u'Species:1423',
#  u'Bacillus subtilis': u'Species:1423',
#  u'Bacillus subtilis 168': u'Species:224308',
#  u'Bacillus subtilis strain 168': u'Species:224308',
#  u'Bacteriol': u'Chemical:',
#  u'C': u'Chemical:',
#  u'C. acetobutylicum': u'Species:1488',
#  u'C. perfringens': u'Species:1502',
#  u'Ca': u'Chemical:',
#  u'Clostridium': u'Species:1488',
#  u'Clostridium acetobutylicum': u'Species:1488',
#  u'Clostridium perfringens': u'Species:1502',
#  u'D-alanine': u'Chemical:CHEBI:15570',
#  u'D-alanine ester': u'Chemical:',
#  u'D-alanyl': u'Chemical:CHEBI:32437',
#  u'D-alanyl-lipoteichoic acid': u'Chemical:C026244',
#  u'D-fructose': u'Chemical:CHEBI:48095',
#  u'D-glucose': u'Chemical:D005947',
#  u'D610E': u'Mutation:p|SUB|D|610|E',
#  u'D628E': u'Mutation:p|SUB|D|628|E',
#  u'D745E': u'Mutation:p|SUB|D|745|E',
#  u'D75S': u'Mutation:p|SUB|D|75|S',
#  u'D795E': u'Mutation:p|SUB|D|795|E',
#  u'DNA primase': u'Gene:9720914',
#  u'DegU': u'Species:10160',
#  u'E. coli': u'Species:562',
#  u'E216A': u'Mutation:p|SUB|E|216|A',
#  u'E216K': u'Mutation:p|SUB|E|216|K',
#  u'E314K': u'Mutation:p|SUB|E|314|K',
#  u'Escherichia coli': u'Species:562',
#  u'FEMS Microbiol': u'Chemical:',
#  u'Glu': u'Chemical:CHEBI:18237',
#  u'H225Y': u'Mutation:p|SUB|H|225|Y',
#  u'H359A': u'Mutation:p|SUB|H|359|A',
#  u'H359R': u'Mutation:p|SUB|H|359|R',
#  u'HPr': u'Chemical:',
#  u'IPTG': u'Chemical:D007544',
#  u'K356E': u'Mutation:p|SUB|K|356|E',
#  u'L-alanine': u'Chemical:CHEBI:16977',
#  u'L-arabinose': u'Chemical:D001089',
#  u'L-asparagine': u'Chemical:CHEBI:17196',
#  u'L. casei': u'Species:1582',
#  u'LTA': u'Chemical:CHEBI:73572',
#  u'Lactobacillus': u'Species:1582',
#  u'Methyl': u'Chemical:CHEBI:32875',
#  u'Mg2+': u'Chemical:CHEBI:18420',
#  u'Mn2+': u'Chemical:CHEBI:29035',
#  u'N': u'Chemical:',
#  u'N-acetylmuramoyl-L-alanine': u'Chemical:CHEBI:28920',
#  u'NAD(P)H': u'Chemical:D009249',
#  u'NADPH': u'Chemical:D009249',
#  u'Nucleotide': u'Chemical:CHEBI:36976',
#  u'Paenibacillus polymyxa': u'Species:1406',
#  u'Phosphate': u'Chemical:CHEBI:26020',
#  u'Production of beta-galactosidase': u'Disease:D016537',
#  u'S. coelicolor': u'Species:1902',
#  u'S. coelicolor A3(2': u'Species:100226',
#  u'SpoIIAA': u'Chemical:',
#  u'Srb': u'Gene:10575',
#  u'Streptomyces coelicolor': u'Species:1902',
#  u'Streptomyces coelicolor A3(2': u'Species:100226',
#  u'T. denticola': u'Species:158',
#  u'T. pallidum': u'Species:160',
#  u'Treponema': u'Disease:C531782',
#  u'Treponema denticola': u'Species:158',
#  u'Treponema denticola ATCC 35405': u'Species:243275',
#  u'Treponema pallidum': u'Species:160',
#  u'WTA': u'Chemical:',
#  u'acrylamide': u'Chemical:D020106',
#  u'alanine': u'Chemical:CHEBI:16449',
#  u'alcohol': u'Chemical:CHEBI:16236',
#  u'aldehyde': u'Chemical:CHEBI:17478',
#  u'amino': u'Chemical:CHEBI:46882',
#  u'amino acid': u'Chemical:CHEBI:33704',
#  u'amino acids': u'Chemical:CHEBI:33709',
#  u'arginine': u'Chemical:CHEBI:29016',
#  u'asparagine': u'Chemical:CHEBI:17196',
#  u'bacteriocin': u'Chemical:CHEBI:48081',
#  u'carbon': u'Chemical:D002244',
#  u'carboxy': u'Chemical:CHEBI:46883',
#  u'carboxyl': u'Chemical:',
#  u'casei': u'Species:1582',
#  u'chloramphenicol': u'Chemical:D002701',
#  u'chloroform': u'Chemical:D002725',
#  u'choline': u'Chemical:D002794',
#  u'cholinephosphate': u'Chemical:D010767',
#  u'enterotoxin': u'Gene:10874406',
#  u'epoxide': u'Chemical:CHEBI:32955',
#  u'erythromycin': u'Chemical:D004917',
#  u'ethanol': u'Chemical:D000431',
#  u'flotillin': u'Chemical:',
#  u'food poisoning': u'Disease:D005517',
#  u'fructose': u'Chemical:D005632',
#  u'galacturonate': u'Chemical:CHEBI:24175',
#  u'galacturonic acid': u'Chemical:C007819',
#  u'gerD': u'Gene:938910',
#  u'glucose': u'Chemical:D005947',
#  u'glutamate': u'Chemical:CHEBI:29987',
#  u'glutamine': u'Chemical:CHEBI:28300',
#  u'glycerol-3-phosphate': u'Chemical:C029620',
#  u'glycerophosphoryl diester': u'Chemical:',
#  u'glycine': u'Chemical:CHEBI:57305',
#  u'guanine': u'Chemical:D006147',
#  u'guanosine': u'Chemical:D006151',
#  u'heat shock': u'Disease:D012769',
#  u'histidine': u'Chemical:CHEBI:27570',
#  u'human': u'Species:9606',
#  u'humans': u'Species:9606',
#  u'hydrogen peroxide': u'Chemical:D006861',
#  u'isopropyl-beta-D-thiogalactopyranoside': u'Chemical:CHEBI:61448',
#  u'lipoteichoic acid': u'Chemical:C009900',
#  u'mammalian': u'Species:9606',
#  u'monosaccharide': u'Chemical:CHEBI:35381',
#  u'nucleotide': u'Chemical:CHEBI:36976',
#  u'nucleotides': u'Chemical:D009711',
#  u'ornithine': u'Chemical:CHEBI:18257',
#  u'penicillin': u'Chemical:D010406',
#  u'pentapeptide': u'Chemical:CHEBI:48545',
#  u'phosphate': u'Chemical:CHEBI:26020',
#  u'phosphoenolpyruvate': u'Chemical:D010728',
#  u'phosphorylated N': u'Chemical:',
#  u'poly(glycerol phosphate)': u'Chemical:C008964',
#  u'poly(groP)': u'Chemical:C008964',
#  u'polyacrylamide': u'Chemical:CHEBI:51135',
#  u'potassium': u'Chemical:D011188',
#  u'potassium chloride': u'Chemical:D011189',
#  u'proline': u'Chemical:CHEBI:26271',
#  u'serine': u'Chemical:C047902',
#  u'sigma G': u'Chemical:',
#  u'sigma H': u'Chemical:',
#  u'sigmaA': u'Chemical:',
#  u'sigmaB': u'Chemical:',
#  u'sigmaF': u'Chemical:',
#  u'sigmaG': u'Chemical:',
#  u'sigmaH': u'Chemical:',
#  u'sigmaK': u'Chemical:',
#  u'sporangium': u'Chemical:',
#  u'succinate': u'Chemical:D019802',
#  u'sugar': u'Chemical:',
#  u'teichoic acid': u'Chemical:CHEBI:30049',
#  u'yeast': u'Species:4932'}

# %%
entity_concept_by_type
# Out:
# {'Action': [('control', [], ['9004507']),
#   ('co-transcribed', [], ['9987136']),
#   ('presence', [], ['10234829']),
#   ('low concentration', [], ['10788508', '10788508']),
#   ('stress-induced increase', [], ['9696771']),
#   ('concentration', [], ['10197994', '10411757']),
#   ('activity',
#    [],
#    ['10323866',
#     '10383978',
#     '10503549',
#     '11069677',
#     '1575712',
#     '1938874',
#     '9696775',
#     '9852014',
#     '10411757']),
#   ('rising level', [], ['10075739']),
#   ('its', [], ['10197994', '10400595', '10468601', '10468601']),
#   ('capacity', [], ['10323866']),
#   ('that', [], ['10197994']),
#   ('depletion', [], ['9852014']),
#   ('absence', [], ['11069677']),
#   ('production',
#    [],
#    ['10075739', '10383978', '10464187', '11069677', '9696775']),
#   ('proper localization', [], ['9922240']),
#   ('synthesis', [], ['1902213']),
#   ('localization', [], ['10747015']),
#   ('activation', [], ['7883171', '8631668']),
#   ('processing', [], ['7883171']),
#   ('proteolytic processing', [], ['1575712']),
#   ('levels', [], ['1898930']),
#   ('level', [], ['10503549', '10503549', '11069677']),
#   ('phosphorylated', [], ['10383978']),
#   ('cell-specific activation', [], ['10323866']),
#   ('action', [], ['10200961']),
#   ('higher concentration', [], ['10788508', '10788508']),
#   ('dephosphorylation', [], ['10234829'])],
#  'Expression': [('expression',
#    [],
#    ['10383978',
#     '10464187',
#     '10468601',
#     '10468601',
#     '10503549',
#     '10767540',
#     '10767540',
#     '11011148',
#     '11064201',
#     '1744042',
#     '3114422',
#     '3114422',
#     '7966271',
#     '8169223',
#     '8231806',
#     '8631668',
#     '9108277',
#     '9401028',
#     '10515909',
#     '10629188',
#     '1898930',
#     '9696771',
#     '9922240']),
#   ('those', [], ['1744042']),
#   ('expressed', [], ['11021934', '1906867', '2111808', '2111808', '2468649'])],
#  'Gene': [('katx',
#    [],
#    ['10503549', '10503549', '10503549', '10503549', '9555886', '10503549']),
#   ('sspl', [], ['10333516']),
#   ('sspj', [], ['9852018']),
#   ('ssph', [], ['10333516']),
#   ('truncated genes', [], ['2163341']),
#   ('sspg', [], ['9852018']),
#   ('ald', [], ['10383978']),
#   ('sspe', [], ['10463184', '1900507']),
#   ('sspb', [], ['1900507']),
#   ('orf10', [], ['10481082']),
#   ('its', [], ['10197994', '10400595', '10468601', '10468601']),
#   ('hag', [], ['9696775']),
#   ('subtilisin', [], ['2496113']),
#   ('abrb', [], ['10754235', '11069677']),
#   ('dnae coding region', [], ['3919021']),
#   ('tap1', [], ['10481082']),
#   ('sp0a', [], ['7642487']),
#   ('cotx', [], ['10400595', '10788508', '10788508', '10788508']),
#   ('cotg', [], ['7814326']),
#   ('cotd', [], ['10075739']),
#   ('cotb', [], ['10788508', '10788508', '10788508', '1518043', '7814326']),
#   ('cotc', [], ['10788508', '10788508', '10788508', '1518043']),
#   ('arae', [], ['9401028']),
#   ('spova', [], ['3114422', '3134591']),
#   ('ftsy', [], ['11021934', '11021934']),
#   ('spoiia', [], ['10754235', '3134591', '7642487']),
#   ('rrnb', [], ['3104146']),
#   ('spoiie',
#    [],
#    ['10234829',
#     '10323866',
#     '10323866',
#     '10476035',
#     '10747015',
#     '10754235',
#     '7642487',
#     '10200961']),
#   ('spoiig',
#    [],
#    ['10801786', '11064201', '1902213', '7642487', '8231806', '9748255']),
#   ('spoiiic', [], ['2163341', '3114422', '7704261']),
#   ('spoiim', [], ['8501065']),
#   ('yvyd', [], ['9852014', '10913081']),
#   ('rocr', [], ['10468601', '7540694']),
#   ('gbsb', [], ['8752328']),
#   ('spoiir', [], ['8631668']),
#   ('phrc', [], ['10464187']),
#   ('rocd', [], ['7540694']),
#   ('roce', [], ['7540694']),
#   ('rocf', [], ['7540694']),
#   ('rocg', [], ['10468601', '10468601', '10468601']),
#   ('rsfa', [], ['10629188']),
#   ('ywhe', [], ['10767540']),
#   ('chev', [], ['8169223']),
#   ('sigma g',
#    [],
#    ['1902213',
#     '1902213',
#     '1906867',
#     '1938874',
#     '2468649',
#     '9004507',
#     '9004507']),
#   ('sigb', [], ['10503549', '10913081']),
#   ('sige', [], ['10383978', '10383978', '10383978', '11011148', '9422603']),
#   ('sigd', [], ['8169223']),
#   ('sigg', [], ['2468649']),
#   ('structural gene', [], ['2163341']),
#   ('sigk', [], ['10075739', '11011148', '2163341', '9422603', '10075739']),
#   ('spoivcb', [], ['2163341', '7704261']),
#   ('sigw', [], ['9683469']),
#   ('smc', [], ['11021934']),
#   ('ykza', [], ['9696771', '9696771']),
#   ('flge', [], ['10481082']),
#   ('genes',
#    [],
#    ['10220166',
#     '10468601',
#     '10481082',
#     '1906867',
#     '2111808',
#     '2468649',
#     '7540694',
#     '7642487',
#     '3086839',
#     '9922240']),
#   ('bacillus subtilis alpha-amylase gene', [], ['7494476']),
#   ('tagf', [], ['1906926']),
#   ('tagb', [], ['1906926']),
#   ('yfhq', [], ['10463184']),
#   ('yfhp', [], ['10463184', '10463184']),
#   ('yfhs', [], ['10463184']),
#   ('yfhr', [], ['10463184']),
#   ('ctc', [], ['1744042', '3919317']),
#   ('gene',
#    [],
#    ['10464187',
#     '11011148',
#     '1744042',
#     '3036777',
#     '7883171',
#     '9004507',
#     '9696771',
#     '1898930']),
#   ('spoiva', [], ['9922240', '9922240']),
#   ('degr', [], ['9108277', '9108277', '9108277']),
#   ('ydae', [], ['10220166']),
#   ('ydag', [], ['10220166']),
#   ('sigma e',
#    [],
#    ['1575712',
#     '1784821',
#     '7883171',
#     '8320224',
#     '8320224',
#     '8501065',
#     '8631668']),
#   ('spo0h rna', [], ['1898930']),
#   ('csfx', [], ['7883171']),
#   ('gerd', [], ['1906867']),
#   ('gere',
#    [],
#    ['10075739',
#     '10075739',
#     '10075739',
#     '10075739',
#     '10400595',
#     '10400595',
#     '10788508',
#     '11011148',
#     '11021934',
#     '1518043',
#     '7814326',
#     '9852018',
#     '10075739',
#     '10075739',
#     '10515909']),
#   ('gbsa', [], ['8752328']),
#   ('it', [], ['8501065', '10503549']),
#   ('dnae', [], ['3086839']),
#   ('orf4', [], ['10481082']),
#   ('fliy', [], ['10481082']),
#   ('kina', [], ['11069677', '11069677', '1569009', '8231806']),
#   ('flip', [], ['10481082']),
#   ('flim', [], ['10481082']),
#   ('flil', [], ['10481082']),
#   ('dltb', [], ['7797557']),
#   ('dltd', [], ['7797557']),
#   ('apre', [], ['2496113']),
#   ('mota', [], ['10481082']),
#   ('motb', [], ['10481082']),
#   ('p23', [], ['3086839']),
#   ('spoiiab', [], ['10476035', '1938874', '1938874', '1938874', '7570023']),
#   ('yfkm', [], ['10220166']),
#   ('itself', [], ['1902213', '2468649', '10200961']),
#   ('structural gene for sigma g', [], ['1938874']),
#   ('sdhc', [], ['3036777']),
#   ('rocg coding region', [], ['10468601']),
#   ('spovg', [], ['1898930']),
#   ('spovd', [], ['8289242']),
#   ('spo0a',
#    [],
#    ['10383978',
#     '10801786',
#     '1569009',
#     '8231806',
#     '9287022',
#     '9658001',
#     '9748255']),
#   ('spo0b', [], ['8231806']),
#   ('spo0f', [], ['1569009', '8231806']),
#   ('spo0h', [], ['1898930', '10411757']),
#   ('rpod', [], ['3127379', '3086839', '3086839', '3086839', '3919021']),
#   ('cwlh', [], ['10515909']),
#   ('nade', [], ['9271869']),
#   ('ykvp', [], ['11011148']),
#   ('flgd', [], ['10481082']),
#   ('amye', [], ['3123701']),
#   ('kdgt', [], ['9846747']),
#   ('kdgr', [], ['9846747']),
#   ('ydhd', [], ['11011148'])],
#  'GeneComplex': [('siga', [], ['3127379']),
#   ('operon', [], ['3036777', '7592487', '8752328']),
#   ('sspn-tlp', [], ['10333516']),
#   ('cwlb', [], ['8093697']),
#   ('spoiia', [], ['10754235', '3134591', '7642487']),
#   ('tagdef', [], ['1906926']),
#   ('translational ywhe-lacz fusion', [], ['10767540']),
#   ('clpc', [], ['9852015', '9852015']),
#   ('spoiig',
#    [],
#    ['10801786', '11064201', '1902213', '7642487', '8231806', '9748255']),
#   ('tagabc', [], ['1906926']),
#   ('rpod', [], ['3127379', '3086839', '3086839', '3086839', '3919021']),
#   ('sigx-ypun', [], ['9139908']),
#   ('spova', [], ['3114422', '3134591']),
#   ('sdh', [], ['3036777']),
#   ('chev-lacz fusion', [], ['8169223']),
#   ('comf-flgm', [], ['9696775'])],
#  'GeneFamily': [('general stress gene', [], ['10503549']),
#   ('class iii heat shock genes', [u'Disease:D012769'], ['9852015']),
#   ('genes',
#    [],
#    ['10220166',
#     '10468601',
#     '10481082',
#     '1906867',
#     '2111808',
#     '2468649',
#     '7540694',
#     '7642487',
#     '3086839',
#     '9922240']),
#   ('mother-cell-specific gene', [], ['7966271']),
#   ('cot', [], ['10075739'])],
#  'GeneProduct': [('yvyd gene product', [], ['9852014']),
#   ('latter', [], ['7797557']),
#   ('former', [], ['7797557']),
#   ('products', [], ['1906926']),
#   ('monocistronic transcript', [], ['9852018']),
#   ('mrna', [], ['11011148']),
#   ('former transcripts', [], ['8093697']),
#   ('product of spoiiab', [], ['1938874']),
#   ('transcript', [], ['3036777']),
#   ('product of a gene', [], ['1938874'])],
#  'PolymeraseComplex': [('sigma e and sigma k rna polymerases',
#    [],
#    ['7966271']),
#   ('sigma(a) and sigma(x) holoenzymes', [], ['9139908']),
#   ('spo0', [], ['10411757']),
#   ('e sigma 43', [], ['3123701']),
#   ('rna polymerase with the forespore-specific sigmag', [], ['9852018']),
#   ('sigma(a)-rna polymerase', [], ['10801786']),
#   ('major vegetative form of rna polymerase', [], ['3123701']),
#   ('sigma e form of rna polymerase', [], ['8289242']),
#   ('e sigma 29', [], ['3104146', '3919317']),
#   ('rna polymerase containing the sigma 54-like factor sigma l',
#    [],
#    ['7592487']),
#   ('yknxyz', [], ['9987136']),
#   ('rna polymerase associated with either sigma f or sigma g',
#    [],
#    ['9004507']),
#   ('rna polymerase containing sigmak', [], ['10400595']),
#   ('key regulatory device', [], ['10411757']),
#   ('core', [], ['2496113']),
#   ('esigmaf', [], ['10503549', '10503549']),
#   ('e sigma h', [], ['1569009', '1898930']),
#   ('esigmab', [], ['10503549']),
#   ('e sigma e', [], ['10463184', '8501065']),
#   ('e sigma d', [], ['8093697']),
#   ('e sigma g', [], ['2468649']),
#   ('e sigma a', [], ['1898930', '7494476', '8093697']),
#   ('vegetative core rna polymerase', [], ['8320224']),
#   ('e sigma 37', [], ['3919317']),
#   ('abc transporters', [], ['9987136']),
#   ('final sigma(k) rna polymerase', [], ['10788508']),
#   ('spo0abd', [], ['9748255']),
#   ('rna polymerase', [], ['9658001', '9658001']),
#   ('sigmak rna polymerase', [], ['10075739']),
#   ('major vegetative rna polymerase', [], ['1898930']),
#   ('sigl-containing rna polymerase', [], ['10468601']),
#   ('rna polymerase holoenzyme', [], ['2496113']),
#   ('core enzyme', [], ['8460143']),
#   ('sigmaa rna polymerase', [], ['10383978']),
#   ('rna polymerase containing sigma g', [], ['1900507', '2468649'])],
#  'Promoter': [('p2', [], ['8320224', '9422603']),
#   ('p3', [], ['9422603']),
#   ('spoiiep', [], ['9658001']),
#   ('p1', [], ['9422603']),
#   ('pw', [], ['9683469']),
#   ('promoter sequences', [], ['9535080']),
#   ('promoters',
#    [],
#    ['10400595',
#     '10503549',
#     '1518043',
#     '3127379',
#     '7679386',
#     '9287022',
#     '9422603',
#     '9422603']),
#   ('promoter region', [], ['10788508']),
#   ('amyp', [], ['7494476']),
#   ('promoter',
#    [],
#    ['10383978',
#     '10383978',
#     '10468601',
#     '10788508',
#     '10801786',
#     '11021934',
#     '1902213',
#     '3036777',
#     '3104146',
#     '3123701',
#     '3919317',
#     '3919317',
#     '7494476',
#     '7592487',
#     '7814326',
#     '7814326',
#     '8231806',
#     '8289242',
#     '9401028',
#     '9658001',
#     '9683469',
#     '9748255',
#     '9846747',
#     '9852015',
#     '9852015']),
#   ('its', [], ['10197994', '10400595', '10468601', '10468601']),
#   ('promoter regions', [], ['1569009']),
#   ('control region', [], ['9108277', '9139908']),
#   ('consensus promoter', [], ['7494476']),
#   ('promoter element', [], ['8169223']),
#   ('one of these promoters', [], ['10400595']),
#   ('spoiiap', [], ['9658001'])],
#  'Protein': [('katx',
#    [],
#    ['10503549', '10503549', '10503549', '10503549', '9555886', '10503549']),
#   ('sigma(h)', [], ['10913081']),
#   ('csf', [], ['10464187']),
#   ('anti-anti-sigma factor', [], ['10476035']),
#   ('primary sigma factor', [], ['9658001']),
#   ('membrane-bound phosphatase', [], ['10476035']),
#   ('alternative sigma factor', [], ['9108277']),
#   ('flotillin', [u'Chemical:'], ['9987136']),
#   ('enzyme', [], ['10200961']),
#   ('purified product of gere', [], ['1518043']),
#   ('arar', [], ['9401028']),
#   ('sigmal', [], ['9852014']),
#   ('sigmah', [], ['10464187', '9287022', '9658001', '9852014', '10411757']),
#   ('sigmak',
#    [],
#    ['10075739', '10075739', '10383978', '10383978', '10383978', '10075739']),
#   ('sigma(k)', [], ['10878124', '11021934', '10515909']),
#   ('sigmae', [], ['10383978']),
#   ('sigma-43', [], ['3036777']),
#   ('sigmag', [], ['10333516', '10333516']),
#   ('sigmaf',
#    [],
#    ['10197994',
#     '10323866',
#     '10323866',
#     '10333516',
#     '10476035',
#     '10503549',
#     '10503549']),
#   ('sigmaa',
#    [],
#    ['10197994',
#     '10383978',
#     '9287022',
#     '9535080',
#     '9658001',
#     '9846747',
#     '9852015',
#     '9852015']),
#   ('sigmab',
#    [],
#    ['10220166',
#     '10503549',
#     '10503549',
#     '10503549',
#     '9535080',
#     '9696771',
#     '9852014',
#     '9852014',
#     '9852015',
#     '9852015',
#     '10503549',
#     '9696771']),
#   ('dksa', [], ['10220166']),
#   ('kinb', [], ['11069677']),
#   ('sigmaw', [], ['9683469']),
#   ('ftsz', [], ['10747015']),
#   ('unphosphorylated spoiiaa', [], ['10323866']),
#   ('spoiie',
#    [],
#    ['10234829',
#     '10323866',
#     '10323866',
#     '10476035',
#     '10747015',
#     '10754235',
#     '7642487',
#     '10200961']),
#   ('spoiiid', [], ['10788508', '10788508']),
#   ('yvyd', [], ['9852014', '10913081']),
#   ('rocr', [], ['10468601', '7540694']),
#   ('sigma(x)', [], ['9139908']),
#   ('pro-sigma e', [], ['7883171']),
#   ('small peptides', [], ['9987136']),
#   ('sigma f',
#    [],
#    ['1575712',
#     '1784821',
#     '1938874',
#     '1938874',
#     '1938874',
#     '7679386',
#     '7883171',
#     '7883171',
#     '8631668',
#     '9004507',
#     '10200961']),
#   ('sigma g',
#    [],
#    ['1902213',
#     '1902213',
#     '1906867',
#     '1938874',
#     '2468649',
#     '9004507',
#     '9004507']),
#   ('sigma d', [], ['2111808', '7679386', '8169223']),
#   ('sigma e',
#    [],
#    ['1575712',
#     '1784821',
#     '7883171',
#     '8320224',
#     '8320224',
#     '8501065',
#     '8631668']),
#   ('sige', [], ['10383978', '10383978', '10383978', '11011148', '9422603']),
#   ('sigma a', [], ['2496113', '7494477', '9658001']),
#   ('sigk', [], ['10075739', '11011148', '2163341', '9422603', '10075739']),
#   ('sigma k', [], ['2163341']),
#   ('sigma h', [], ['7494477', '9658001', '1898930']),
#   ('sigma w', [], ['9987136']),
#   ('racx', [], ['9987136']),
#   ('yock', [], ['10220166']),
#   ('phosphorylated spo0a', [], ['11064201']),
#   ('early-sporulation sigma factor', [], ['9658001']),
#   ('yfhm', [], ['9987136']),
#   ('sinr', [], ['7642487']),
#   ('comk', [], ['9108277', '9696775']),
#   ('yfhp', [], ['10463184', '10463184']),
#   ('rpos', [], ['9696771']),
#   ('ykrq', [], ['11069677']),
#   ('whig gene product', [], ['7679386']),
#   ('earlier-acting sigma factor', [], ['10383978']),
#   ('spoiva', [], ['9922240', '9922240']),
#   ('phosphorylated form of spoiiaa', [], ['10476035']),
#   ('non-haem bromoperoxidase', [], ['9987136']),
#   ('serine kinase', [u'Chemical:C047902'], ['7570023']),
#   ('sigma b', [], ['1744042', '8460143', '8460143', '9271869']),
#   ('forespore-specific sigma factor', [], ['10333516']),
#   ('anti-sigma factor', [], ['10476035']),
#   ('sigma(e)', [], ['10878124']),
#   ('spoiiaa-p', [], ['10234829']),
#   ('gere',
#    [],
#    ['10075739',
#     '10075739',
#     '10075739',
#     '10075739',
#     '10400595',
#     '10400595',
#     '10788508',
#     '11011148',
#     '11021934',
#     '1518043',
#     '7814326',
#     '9852018',
#     '10075739',
#     '10075739',
#     '10515909']),
#   ('serine phosphatase', [u'Chemical:C047902'], ['10323866']),
#   ('ydjp', [], ['9987136']),
#   ('later-acting sigma factor', [], ['10383978']),
#   ('phosphatase protein', [], ['10323866']),
#   ('pbp4*', [], ['9987136']),
#   ('sigma(b)', [], ['10913081']),
#   ('ytxh', [], ['10913081']),
#   ('factor', [], ['2111808', '7883171']),
#   ('rsbw', [], ['8460143']),
#   ('amino acid racemase',
#    [u'Chemical:CHEBI:33704', u'Chemical:CHEBI:46882'],
#    ['9987136']),
#   ('dnak', [], ['10220166']),
#   ('sigma(54)', [], ['10468601']),
#   ('dnase i', [], ['10788508']),
#   ('kind', [], ['11069677', '11069677']),
#   ('kine', [], ['11069677']),
#   ('spo0a~p', [], ['11064201', '11069677', '11069677', '9748255']),
#   ('kinc', [], ['11069677', '11069677']),
#   ('kina', [], ['11069677', '11069677', '1569009', '8231806']),
#   ('epoxide hydrolase', [u'Chemical:CHEBI:32955'], ['9987136']),
#   ('yhdn', [], ['10220166']),
#   ('forespore-specific sigma factor for rna polymerase', [], ['10333516']),
#   ('mother cell transcription factor sigmae', [], ['9922240']),
#   ('spoiiab', [], ['10476035', '1938874', '1938874', '1938874', '7570023']),
#   ('spoiiaa', [], ['10476035', '7570023']),
#   ('itself', [], ['1902213', '2468649', '10200961']),
#   ('penicillin binding protein', [u'Chemical:D010406'], ['9987136']),
#   ('protein', [], ['7883171']),
#   ('ytei', [], ['9987136']),
#   ('s1', [], ['3036777', '3134591']),
#   ('sigma(g)', [], ['10767540', '10878124', '10629188']),
#   ('sigmad', [], ['9108277', '9108277', '9535080', '9696775']),
#   ('sigma factors', [], ['7679386']),
#   ('spo0a',
#    [],
#    ['10383978',
#     '10801786',
#     '1569009',
#     '8231806',
#     '9287022',
#     '9658001',
#     '9748255']),
#   ('transcription factor', [], ['1902213', '9683469']),
#   ('ykvd', [], ['11069677']),
#   ('product of the sigg gene', [], ['2468649']),
#   ('yuag', [], ['9987136']),
#   ('sigma(a)', [], ['11064201']),
#   ('ctsr', [], ['9852015']),
#   ('sigma 28', [], ['2111808']),
#   ('flgm', [], ['9696775']),
#   ('active form', [], ['10476035']),
#   ('major transcription factor', [], ['11064201']),
#   ('sigma(f)', [], ['10767540', '10629188']),
#   ('rna polymerase sigma factor sigma k', [], ['7814326']),
#   ('forespore-specific sigmaf', [], ['9555886'])],
#  'ProteinFamily': [('sigma factor', [], ['10878124']),
#   ('ntrc/nifa', [], ['10468601']),
#   ('bacteriocin precursor polypeptides',
#    [u'Chemical:CHEBI:48081'],
#    ['9987136']),
#   ('sporulation sigma factors', [], ['10878124']),
#   ('catabolic glutamate dehydrogenase',
#    [u'Chemical:CHEBI:29987'],
#    ['10468601']),
#   ('proteins', [], ['10220166']),
#   ('homologues of signal peptide peptidase', [], ['9987136']),
#   ('acid-soluble proteins', [], ['1900507']),
#   ('kinases', [], ['11069677']),
#   ('dna-binding protein', [], ['1518043']),
#   ('potassium ion channel proteins', [u'Chemical:D011188'], ['10220166']),
#   ('rna polymerase sigma factors', [], ['1784821'])],
#  'Regulon': [('regulon',
#    [],
#    ['10503549',
#     '10503549',
#     '1906867',
#     '2111808',
#     '8501065',
#     '9555886',
#     '9852014',
#     '9987136',
#     '9696771']),
#   ('stress regulons', [], ['9696771']),
#   ('regulons', [], ['9852014'])],
#  'Site': [('control region', [], ['9108277', '9139908']),
#   ('guanosine residue', [u'Chemical:D006151'], ['3036777']),
#   ('transcriptional start site', [], ['10075739']),
#   ('p-independent terminator', [], ['9846747']),
#   ('transcriptional start points', [], ['10503549']),
#   ('sequence', [], ['10468601']),
#   ('dna sequences', [], ['9422603']),
#   ('-35 region', [], ['10400595']),
#   ('uas', [], ['10468601', '10468601']),
#   ('transcription start points', [], ['3134591']),
#   ('-35 and -10 hexamers', [], ['7494476']),
#   ('site', [], ['10400595', '10788508']),
#   ('sites', [], ['10788508']),
#   ('start point of transcription', [], ['9535080']),
#   ('downstream site', [], ['10075739']),
#   ('-10 and -35 sequences', [], ['10503549']),
#   ('enhancer-like elements', [], ['10468601']),
#   ('upstream activating sequences', [], ['10468601']),
#   ('upstream site', [], ['10075739']),
#   ('promoter elements', [], ['9139908'])],
#  'Transcription': [('transcription',
#    [],
#    ['10075739',
#     '10075739',
#     '10075739',
#     '10383978',
#     '10400595',
#     '10463184',
#     '10464187',
#     '10754235',
#     '10788508',
#     '10788508',
#     '10788508',
#     '10788508',
#     '10788508',
#     '10801786',
#     '11011148',
#     '11064201',
#     '11069677',
#     '1902213',
#     '1938874',
#     '1938874',
#     '2111808',
#     '2468649',
#     '3123701',
#     '3127379',
#     '7883171',
#     '8169223',
#     '8289242',
#     '8460143',
#     '9108277',
#     '9108277',
#     '9287022',
#     '9696775',
#     '9696775',
#     '9748255',
#     '9846747',
#     '9852018',
#     '10075739']),
#   ('transcribed',
#    [],
#    ['10463184',
#     '10468601',
#     '11011148',
#     '1898930',
#     '1900507',
#     '2496113',
#     '3036777',
#     '8093697',
#     '8501065',
#     '8752328',
#     '9004507',
#     '10075739',
#     '1898930',
#     '3919021',
#     '9852018']),
#   ('unstressed transcription', [], ['9852015'])]}

# %%
# Combined the annotated text to query; Failed :(
# res = pubtator_cli.get_concepts_rawtxtlist('all', [' '.join(words) for words in entity_by_type.values()])
# for ent_type, ent_strs in entity_by_type.iteritems():
#     entity_by_type[ent_type] = [(ent_str, [concept['obj'] for concept in pubtator_cli.get_concepts_rawtxt('gene', ent_str)['denotations']]) for ent_str in ent_strs]

# %%
io.write_json(json.dumps(entity_concept_by_type), 'entity_concept_by_type.json')
io.write_obj(entity_concept_by_type, 'entity_concept_by_type.pkl')

# %%
# Test1
text = 'A kinetic model identifies phosphorylated estrogen receptor-a (ERa) as a critical regulator of ERa dynamics in breast cancer.'
pubtator_cli.get_concepts_rawtxtlist('chemical', text.split())

# %%
# Test2
pubtator_cli.get_concepts_pmid('chemical', '19894120')

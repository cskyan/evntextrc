# %%
import os

import numpy as np
import pandas as pd

from bionlp.util import fs, io, func


# DATA_PATH = '../../data/bioevent/bnlpst/bb2016/ent-cv/'
# perf_paths = ['ent%i/perf_avg_clf.xlsx' % i for i in range(2)]
# perf_labels = ['Bacteria','Location']
# perfs = [pd.read_excel(os.path.join(DATA_PATH, fpath)) for fpath in perf_paths]


# DATA_PATH = '../../data/bioevent/bnlpst/bb2016/evnt-cv/'
# perf_paths = ['perf_avg_clf.xlsx']
# perf_labels += ['Lives_In']
# perfs += [pd.read_excel(os.path.join(DATA_PATH, fpath)) for fpath in perf_paths]


DATA_PATH = '../../data/bioevent/bnlpst/bgi2011/ent-cv/'
perf_paths = ['ent%i/perf_avg_clf.xlsx' % i for i in range(11)]
perf_labels = ['Action', 'Agent', 'Entity', 'Gene', 'Member', 'Promoter', 'Protein', 'Regulon', 'Site', 'Target', 'Transcription']
perfs = [pd.read_excel(os.path.join(DATA_PATH, fpath)) for fpath in perf_paths]

DATA_PATH = '../../data/bioevent/bnlpst/bgi2011/evnt-cv/'
perf_paths = ['%i/perf_avg_clf.xlsx' % i for i in range(10)]
perf_labels += ['ActionTarget', 'BindTo', 'Interaction', 'PromoterDependence', 'PromoterOf', 'RegulonDependence', 'RegulonMember', 'SiteOf', 'TranscriptionBy', 'TranscriptionFrom']
perfs += [pd.read_excel(os.path.join(DATA_PATH, fpath)) for fpath in perf_paths]

# %%
all_perf = pd.concat(perfs, axis=1)
all_perf.columns = perf_labels
all_perf.to_excel('all_perf.xlsx')
all_perf
# Out:
#                 Action       Agent      Entity        Gene      Member  \
# Accuracy      0.973110    0.864179    0.856863    0.905708    0.965553
# Precision     0.921818    0.665817    0.089274    0.321448    0.481905
# Recall        0.926364    0.750000    0.650000    0.550000    0.800000
# F score       0.920132    0.696671    0.148951    0.374584    0.541111
# Train time  603.734824  696.145884  512.576287  710.306127  676.998796
# Test time     1.646147    1.591767    1.555362    1.788193    2.149001
#
#               Promoter     Protein     Regulon        Site      Target  \
# Accuracy      0.967185    0.923900    0.988060    0.935820    0.772759
# Precision     0.698254    0.515000    0.675000    0.447262    0.612791
# Recall        0.900000    0.716667    1.000000    0.800000    0.727143
# F score       0.771726    0.504545    0.773333    0.520937    0.655399
# Train time  469.788338  595.323410  391.121794  591.959107  660.292920
# ...
